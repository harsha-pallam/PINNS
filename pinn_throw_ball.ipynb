# %%
   pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Downloading torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl (821.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 1.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu12==11.3.0.4
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 5.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu12==11.7.1.2
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 7.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu12==12.6.77
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 KB 30.1 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12==12.6.85
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 33.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu12==10.3.7.77
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 28.4 MB/s eta 0:00:0000:0100:01
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 44.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch) (3.0.3)
# Collecting networkx
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 31.9 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-nvtx-cu12==12.6.77
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 KB 8.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==9.5.1.17
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 6.3 MB/s eta 0:00:0000:0100:01
# Collecting filelock
#   Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/hp/.local/lib/python3.10/site-packages (from torch) (4.12.2)
# Collecting fsspec
#   Downloading fsspec-2025.5.1-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 KB 22.9 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.26.2
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 12.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparselt-cu12==0.6.3
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 9.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu12==12.5.4.2
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 14.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufile-cu12==1.11.1.6
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 38.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.6.80
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 42.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu12==12.6.4.1
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 9.0 MB/s eta 0:00:0000:0100:01
# Collecting triton==3.3.1
#   Downloading triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 13.5 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 26.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools>=40.8.0 in /usr/lib/python3/dist-packages (from triton==3.3.1->torch) (59.6.0)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 22.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, fsspec, filelock, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
# Successfully installed filelock-3.18.0 fsspec-2025.5.1 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 sympy-1.14.0 torch-2.7.1 triton-3.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import numpy as np  
import matplotlib.pyplot as plt

# %%
# --------------------------
# 1. Generate Synthetic Data
# --------------------------

# Physics parameters
g = 9.8        # acceleration due to gravity
h0 = 1.0       # initial height
v0 = 10.0      # initial velocity

# True (analytical) solution h(t) = h0 + v0*t - 0.5*g*t^2
def true_solution(t):
    return h0 + v0*t - 0.5*g*(t**2)

# Generate some time points
t_min, t_max = 0.0, 2.0
N_data = 10
t_data = np.linspace(t_min, t_max, N_data)

# Generate synthetic "experimental" heights with noise
np.random.seed(0)
noise_level = 0.7
h_data_exact = true_solution(t_data)
h_data_noisy = h_data_exact + noise_level*np.random.randn(N_data)

# Convert to PyTorch tensors
t_data_tensor = torch.tensor(t_data, dtype=torch.float32).view(-1, 1)
h_data_tensor = torch.tensor(h_data_noisy, dtype=torch.float32).view(-1, 1)

# %%
# --------------------------------------------------------
# 2. Define a small feed-forward neural network for h(t)
# --------------------------------------------------------
class PINN(nn.Module):
    def __init__(self, n_hidden=20):
        super(PINN, self).__init__()
        # A simple MLP with 2 hidden layers
        self.net = nn.Sequential(
            nn.Linear(1, n_hidden),
            nn.Tanh(),
            nn.Linear(n_hidden, n_hidden),
            nn.Tanh(),
            nn.Linear(n_hidden, 1)
        )

    def forward(self, t):
        """
        Forward pass: input shape (batch_size, 1) -> output shape (batch_size, 1)
        """
        return self.net(t)

# Instantiate the model
model = PINN(n_hidden=20)

# %%
# --------------------------------
# 3. Helper for Automatic Diff
# --------------------------------
def derivative(y, x):
    """
    Computes dy/dx using PyTorch's autograd.
    y and x must be tensors with requires_grad=True for x.
    """
    return torch.autograd.grad(
        y, x,
        grad_outputs=torch.ones_like(y),
        create_graph=True
    )[0]

# %%
# ----------------------------------------
# 4. Define the Loss Components (PINN)
# ----------------------------------------

# We have:
#    (1) Data loss (fit noisy data)
#    (2) ODE loss: dh/dt = v0 - g * t
#    (3) Initial condition loss: h(0) = h0

def physics_loss(model, t):
    """
    Compare d(h_pred)/dt with the known expression (v0 - g t).
    """
    # t must have requires_grad = True for autograd to work
    t.requires_grad_(True)

    h_pred = model(t)
    dh_dt_pred = derivative(h_pred, t)

    # For each t, physics says dh/dt = v0 - g * t
    dh_dt_true = v0 - g * t

    loss_ode = torch.mean((dh_dt_pred - dh_dt_true)**2)
    return loss_ode

def initial_condition_loss(model):
    """
    Enforce h(0) = h0.
    """
    # Evaluate at t=0
    t0 = torch.zeros(1, 1, dtype=torch.float32, requires_grad=False)
    h0_pred = model(t0)
    return (h0_pred - h0).pow(2).mean()

def data_loss(model, t_data, h_data):
    """
    MSE between predicted h(t_i) and noisy measurements h_data.
    """
    h_pred = model(t_data)
    return torch.mean((h_pred - h_data)**2)

# %%
# ---------------------------------------
# 5. Training Setup
# ---------------------------------------
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# Hyperparameters for weighting the loss terms
lambda_data = 1.0
lambda_ode  = 1.0
lambda_ic   = 1.0

# For logging
num_epochs = 4000
print_every = 200

# %%
# ---------------------------------------
# 6. Training Loop
# ---------------------------------------
model.train()
for epoch in range(num_epochs):
    optimizer.zero_grad()

    # Compute losses
    l_data = data_loss(model, t_data_tensor, h_data_tensor)
    l_ode  = physics_loss(model, t_data_tensor)
    l_ic   = initial_condition_loss(model)

    # Combined loss
    loss = lambda_data * l_data + lambda_ode * l_ode + lambda_ic * l_ic

    # Backprop
    loss.backward()
    optimizer.step()

    # Print progress
    if (epoch+1) % print_every == 0:
        print(f"Epoch {epoch+1}/{num_epochs}, "
              f"Total Loss = {loss.item():.6f}, "
              f"Data Loss = {l_data.item():.6f}, "
              f"ODE Loss = {l_ode.item():.6f}, "
              f"IC Loss = {l_ic.item():.6f}")
# Out:
# Epoch 200/4000, Total Loss = 0.231129, Data Loss = 0.216798, ODE Loss = 0.001739, IC Loss = 0.012592
# Epoch 400/4000, Total Loss = 0.194181, Data Loss = 0.174926, ODE Loss = 0.007096, IC Loss = 0.012158
# Epoch 600/4000, Total Loss = 0.163153, Data Loss = 0.149867, ODE Loss = 0.000587, IC Loss = 0.012699
# Epoch 800/4000, Total Loss = 0.179465, Data Loss = 0.150145, ODE Loss = 0.020813, IC Loss = 0.008507
# Epoch 1000/4000, Total Loss = 0.155780, Data Loss = 0.142612, ODE Loss = 0.000434, IC Loss = 0.012734
# Epoch 1200/4000, Total Loss = 0.154296, Data Loss = 0.141358, ODE Loss = 0.000361, IC Loss = 0.012577
# Epoch 1400/4000, Total Loss = 0.153639, Data Loss = 0.139405, ODE Loss = 0.000600, IC Loss = 0.013635
# Epoch 1600/4000, Total Loss = 0.153467, Data Loss = 0.141572, ODE Loss = 0.000607, IC Loss = 0.011289
# Epoch 1800/4000, Total Loss = 0.152106, Data Loss = 0.139204, ODE Loss = 0.000318, IC Loss = 0.012584
# Epoch 2000/4000, Total Loss = 0.151916, Data Loss = 0.139159, ODE Loss = 0.000597, IC Loss = 0.012159
# Epoch 2200/4000, Total Loss = 0.153696, Data Loss = 0.135188, ODE Loss = 0.001767, IC Loss = 0.016741
# Epoch 2400/4000, Total Loss = 0.152075, Data Loss = 0.136381, ODE Loss = 0.000925, IC Loss = 0.014769
# Epoch 2600/4000, Total Loss = 0.150954, Data Loss = 0.137810, ODE Loss = 0.000309, IC Loss = 0.012835
# Epoch 2800/4000, Total Loss = 0.152101, Data Loss = 0.141131, ODE Loss = 0.001560, IC Loss = 0.009410
# Epoch 3000/4000, Total Loss = 0.155569, Data Loss = 0.136383, ODE Loss = 0.005662, IC Loss = 0.013523
# Epoch 3200/4000, Total Loss = 0.150542, Data Loss = 0.137627, ODE Loss = 0.000292, IC Loss = 0.012622
# Epoch 3400/4000, Total Loss = 0.150868, Data Loss = 0.135593, ODE Loss = 0.000813, IC Loss = 0.014462
# Epoch 3600/4000, Total Loss = 0.153804, Data Loss = 0.137812, ODE Loss = 0.003114, IC Loss = 0.012877
# Epoch 3800/4000, Total Loss = 0.150922, Data Loss = 0.137278, ODE Loss = 0.001180, IC Loss = 0.012464
# Epoch 4000/4000, Total Loss = 0.150516, Data Loss = 0.138395, ODE Loss = 0.000524, IC Loss = 0.011596

# %%
# ---------------------------------------
# 7. Evaluate the Trained Model
# ---------------------------------------
model.eval()
t_plot = np.linspace(t_min, t_max, 100).reshape(-1, 1).astype(np.float32)
t_plot_tensor = torch.tensor(t_plot, requires_grad=True)
h_pred_plot = model(t_plot_tensor).detach().numpy()

# True solution (for comparison)
h_true_plot = true_solution(t_plot)

# Plot results
plt.figure(figsize=(8, 5))
plt.scatter(t_data, h_data_noisy, color='red', label='Noisy Data')
plt.plot(t_plot, h_true_plot, 'k--', label='Exact Solution')
plt.plot(t_plot, h_pred_plot, 'b', label='PINN Prediction')
plt.xlabel('t')
plt.ylabel('h(t)')
plt.legend()
plt.title('PINN for Ball Trajectory')
plt.grid(True)
plt.show()
